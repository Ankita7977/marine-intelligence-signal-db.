# %% [markdown]
# # Marine Intelligence Signal Normalization
#
# This notebook demonstrates how AIS, weather, and hydrology datasets
# are normalized into a unified schema.

# %% [markdown]
# **Import Libraries**

# %%
import pandas as pd

# %% [markdown]
# **Load CSV Files**

# %%
import pandas as pd

ais = pd.read_csv("../data/ais_standardized.csv")
weather = pd.read_csv("../data/weather_standardized.csv")
water = pd.read_csv("../data/water_standardized.csv")

print("AIS rows:", len(ais))
print("Weather rows:", len(weather))
print("Water rows:", len(water))
# Out:
# AIS rows: 7239758
# Weather rows: 366
# Water rows: 312

# %% [markdown]
# **Preview Dataset**

# %%
ais.head()
# Out:
#    source_id            timestamp  latitude  longitude  feature_type  \
# 0  368084090  2022-01-01 00:00:00  29.93174  -89.99243  vessel_speed
# 1  368140160  2022-01-01 00:00:00  30.33475  -87.14429  vessel_speed
# 2  366941830  2022-01-01 00:00:02  29.30919  -94.79702  vessel_speed
# 3  316005971  2022-01-01 00:00:06  46.50268  -84.35674  vessel_speed
# 4  316004054  2022-01-01 00:00:07  46.50326  -84.37506  vessel_speed
#
#    normalized_value source_reference
# 0               6.0              AIS
# 1               0.0              AIS
# 2               0.0              AIS
# 3               2.4              AIS
# 4               0.3              AIS

# %%
weather.head()
water.head()
# Out:
#      source_id   timestamp  latitude  longitude   feature_type  \
# 0  US1TXTV0053  2022-01-05       NaN        NaN  precipitation
# 1  US1TXTV0053  2022-01-06       NaN        NaN  precipitation
# 2  US1TXTV0053  2022-01-09       NaN        NaN  precipitation
# 3  US1TXTV0053  2022-01-10       NaN        NaN  precipitation
# 4  US1TXTV0053  2022-01-11       NaN        NaN  precipitation
#
#    normalized_value source_reference
# 0               0.0             NOAA
# 1               0.0             NOAA
# 2               0.0             NOAA
# 3               0.0             NOAA
# 4               0.0             NOAA

# %% [markdown]
# **Define Unified Schema**

# %%
columns = [
"source_id",
"timestamp",
"latitude",
"longitude",
"feature_type",
"normalized_value",
"source_reference"
]

# %% [markdown]
# **Normalize Datasets**

# %%
ais = ais[columns]
weather = weather[columns]
water = water[columns]

# %% [markdown]
# **Show Dataset Size**

# %%
signals.shape
# Out:
# (7240436, 7)

# %% [markdown]
# **Merge All Signals**

# %%
signals = pd.concat([ais, weather, water], ignore_index=True)

signals.head()
# Out:
#    source_id            timestamp  latitude  longitude  feature_type  \
# 0  368084090  2022-01-01 00:00:00  29.93174  -89.99243  vessel_speed
# 1  368140160  2022-01-01 00:00:00  30.33475  -87.14429  vessel_speed
# 2  366941830  2022-01-01 00:00:02  29.30919  -94.79702  vessel_speed
# 3  316005971  2022-01-01 00:00:06  46.50268  -84.35674  vessel_speed
# 4  316004054  2022-01-01 00:00:07  46.50326  -84.37506  vessel_speed
#
#    normalized_value source_reference
# 0               6.0              AIS
# 1               0.0              AIS
# 2               0.0              AIS
# 3               2.4              AIS
# 4               0.3              AIS

# %% [markdown]
# ## Conclusion
#
# AIS vessel signals, weather signals, and hydrology signals were
# successfully normalized into a unified schema.
#
# This dataset will be ingested into the Marine Intelligence Signal
# Database using the ingestion pipeline.
